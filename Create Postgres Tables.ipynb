# %%
import pandas as pd
import sqlalchemy

# %%
#Dataframe 1: Boston Crime Data
crime_df = pd.io.parsers.read_csv('Database_Files/Boston_Crime.csv', dtype='str')
crime_df
# Out:
#        Unnamed: 0 INCIDENT_NUMBER OFFENSE_CODE  \
# 0               0      I182070945          619
# 1               1      I182070943         1402
# 2               2      I182070941         3410
# 3               3      I182070940         3114
# 4               4      I182070938         3114
# 5               5      I182070936         3820
# 6               6      I182070933          724
# 7               7      I182070932         3301
# 8               8      I182070931          301
# 9               9      I182070929         3301
# 10             10      I182070928         3301
# 11             11      I182070927         3114
# 12             12      I182070923         3108
# 13             13      I182070922         2647
# 14             14      I182070921         3201
# 15             15      I182070920         3006
# 16             16      I182070919         3301
# 17             17      I182070918         3305
# 18             18      I182070917         2647
# ...

# %%
#Dataframe 2:Boston_ZipCodes 
zip_df = pd.io.parsers.read_csv('Database_Files/ZipCode_data.csv', dtype='str')
zip_df
# Out:
#    Zip Code        District
# 0      02108         Boston
# 1      02109         Boston
# 2      02110         Boston
# 3      02111         Boston
# 4      02112         Boston
# 5      02113         Boston
# 6      02114         Boston
# 7      02115         Boston
# 8      02116         Boston
# 9      02117         Boston
# 10     02118        Roxbury
# 11     02119        Roxbury
# 12     02120        Roxbury
# 13     02121     Dorchester
# 14     02122     Dorchester
# 15     02123         Boston
# 16     02124     Dorchester
# 17     02125     Dorchester
# 18     02126       Mattapan
# 19     02127   South Boston
# 20     02128    East Boston
# 21     02129    Charlestown
# 22     02130  Jamaica Plain
# 23     02131    Roslindale
# 24     02132   West Roxbury
# 25     02133         Boston
# 26     02134        Allston
# 27     02135       Brighton
# 28     02136      Hyde Park
# 29     02137      Hyde Park

# %%
#Dataframe 3:Census Race Stats 
census_df = pd.io.parsers.read_csv('Database_Files/Census.csv', dtype='str')
census_df
# Out:
#    Unnamed: 0 Unnamed: 0.1 Zip Code       District White Pop Afr Am Pop  \
# 0           0            0    02108         Boston    3563.0      223.0
# 1           1            1    02109         Boston    3419.0      157.0
# 2           2            2    02110         Boston    1896.0       92.0
# 3           3            3    02111         Boston    3250.0      156.0
# 4           5            5    02113         Boston    7022.0       52.0
# 5           6            6    02114         Boston   10504.0      613.0
# 6           7            7    02115         Boston   19506.0     2421.0
# 7           8            8    02116         Boston   17684.0     1297.0
# 8          10           10    02118        Roxbury   14830.0     4467.0
# 9          11           11    02119        Roxbury    4257.0    16232.0
# 10         12           12    02120        Roxbury    6990.0     3989.0
# 11         13           13    02121     Dorchester    2034.0    19583.0
# ...

# %%
#Dataframe 4:Districts
bpd_df = pd.io.parsers.read_csv('Database_Files/Police_Districts.csv', dtype='str')
bpd_df
# Out:
#    Unnamed: 0 District_Codes        District_Address        District
# 0           0             A7         69 Paris Street     East Boston
# 1           1             B2  2400 Washington Street         Roxbury
# 2           2             B3   1165 Blue Hill Avenue        Mattapan
# 3           3             C6       101 West Broadway    South Boston
# 4           4            C11        40 Gibson Street      Dorchester
# 5           5             D4     650 Harrison Avenue          Boston
# 6           6            D14   301 Washington Street        Brighton
# 7           7             E5      1708 Centre Street    West Roxbury
# 8           8            E13  3347 Washington Street   Jamaica Plain
# 9           9            E18   1249 Hyde Park Avenue       Hyde Park
# 10         10             A1   40 New Sudbury Street     Charlestown
# 11         11            A15   40 New Sudbury Street          Boston

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:FuckOff666!@localhost:5432/ETL-Proj2')
connection = engine.connect()
print(engine.table_names())
# Out:
# []

# %%
table_name = 'bostoncrime'
crime_df.to_sql(table_name, connection)
print ("done1")

table_name2 = 'bostonzipcodes'
zip_df.to_sql(table_name2, connection)
print ("done2")

table_name3 = 'bostonracestats'
census_df.to_sql(table_name3, connection)
print ("done3")

table_name4 = 'bostonpd'
bpd_df.to_sql(table_name4, connection)
print ("done4")
# Out:
# done1
# done2
# done3
# done4

# %%
table_name4 = 'bostonpd'
bpd_df.to_sql(table_name4, connection)
print ("done4")
# Out:
# done4

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
crime_data_to_load = "data/Boston Crime Data.csv"
zip_data_to_load = "data/Boston_ZipCodes.csv"
dist_data_to_load = "data/districts.csv"

# Read Data 
crime_data = pd.read_csv(crime_data_to_load)
# Prevent truncation of zero in Zipcode 
zip_data = pd.io.parsers.read_csv(zip_data_to_load, dtype={'Zip Code ': 'str'}).set_index('Zip Code ')
# zip_data = pd.read_csv(zip_data_to_load)
dist_data = pd.read_csv(dist_data_to_load)




# Combine the data into a single dataset
# data_combine = pd.merge(mouse_data,clinical_data, how='left', on=["Mouse ID", "Mouse ID"])
# Display the data table for preview
zip_data.head
# Out:
# <bound method NDFrame.head of                 District
# Zip Code
# 02108             Boston
# 02109             Boston
# 02110             Boston
# 02111             Boston
# 02112             Boston
# 02113             Boston
# 02114             Boston
# 02115             Boston
# 02116             Boston
# 02117             Boston
# 02118            Roxbury
# 02119            Roxbury
# 02120            Roxbury
# 02121         Dorchester
# 02122         Dorchester
# 02123             Boston
# 02124         Dorchester
# 02125         Dorchester
# 02126           Mattapan
# 02127       South Boston
# 02128        East Boston
# 02129        Charlestown
# 02130      Jamaica Plain
# 02131        Roslindale
# 02132       West Roxbury
# 02133             Boston
# 02134            Allston
# 02135           Brighton
# 02136          Hyde Park
# 02137          Hyde Park>

# %% [markdown]
# #                                    Transformation - Crime Data

# %%
crime_data.columns
# Out:
# Index(['INCIDENT_NUMBER', 'OFFENSE_CODE', 'OFFENSE_CODE_GROUP',
#        'OFFENSE_DESCRIPTION', 'DISTRICT', 'REPORTING_AREA', 'SHOOTING',
#        'OCCURRED_ON_DATE', 'YEAR', 'MONTH', 'DAY_OF_WEEK', 'HOUR', 'UCR_PART',
#        'STREET', 'Lat', 'Long', 'Location'],
#       dtype='object')

# %%
# kept occurred_on_date because the stripped out date didnt contain "day", easier to parse out the date later into the units needed 
Crime_data_trunc = crime_data[['OFFENSE_CODE','OFFENSE_CODE_GROUP',
       'OFFENSE_DESCRIPTION', 'DISTRICT', 'REPORTING_AREA', 'SHOOTING',
        'OCCURRED_ON_DATE']]

# %%
Crime_data_trunc.set_index('DISTRICT')
# Out:
#           OFFENSE_CODE                OFFENSE_CODE_GROUP  \
# DISTRICT
# D14                619                           Larceny
# C11               1402                         Vandalism
# D4                3410                             Towed
# D4                3114              Investigate Property
# B3                3114              Investigate Property
# C11               3820   Motor Vehicle Accident Response
# B2                 724                        Auto Theft
# B2                3301                   Verbal Disputes
# C6                 301                           Robbery
# C11               3301                   Verbal Disputes
# C6                3301                   Verbal Disputes
# C6                3114              Investigate Property
# D4                3108              Fire Related Reports
# B3                2647                             Other
# B3                3201                     Property Lost
# NaN               3006                Medical Assistance
# C11               3301                   Verbal Disputes
# D4                3305  Assembly or Gathering Violations
# B2                2647                             Other
# B2                 614        Larceny From Motor Vehicle
# NaN               3006                Medical Assistance
# A1                3801   Motor Vehicle Accident Response
# B3                3006                Medical Assistance
# E5                3803   Motor Vehicle Accident Response
# B2                 522              Residential Burglary
# NaN               3831   Motor Vehicle Accident Response
# D4                3006                Medical Assistance
# C11                802                    Simple Assault
# C11               2007      Restraining Order Violations
# B3                2900                             Other
# ...                ...                               ...
# D4                3125                   Warrant Arrests
# D4                 623                           Larceny
# A1                 403                Aggravated Assault
# A1                3125                   Warrant Arrests
# B2                3125                   Warrant Arrests
# B2                 619                           Larceny
# B2                3125                   Warrant Arrests
# B2                 802                    Simple Assault
# B2                3125                   Warrant Arrests
# D4                 629                           Larceny
# D4                3125                   Warrant Arrests
# A1                3125                   Warrant Arrests
# A1                 339                           Robbery
# E13               3125                   Warrant Arrests
# B2                2907                        Violations
# B2                2910                        Violations
# C11               3125                   Warrant Arrests
# C11               3125                   Warrant Arrests
# B3                 403                Aggravated Assault
# B3                3125                   Warrant Arrests
# A1                3125                   Warrant Arrests
# A1                1848                    Drug Violation
# A1                1849                    Drug Violation
# E13               1864                    Drug Violation
# E13               3125                   Warrant Arrests
# D4                3125                   Warrant Arrests
# E18                111                          Homicide
# E18               3125                   Warrant Arrests
# E13               3125                   Warrant Arrests
# D4                3125                   Warrant Arrests
#
#                                      OFFENSE_DESCRIPTION REPORTING_AREA  \
# DISTRICT
# D14                                   LARCENY ALL OTHERS            808
# C11                                            VANDALISM            347
# D4                                   TOWED MOTOR VEHICLE            151
# D4                                  INVESTIGATE PROPERTY            272
# B3                                  INVESTIGATE PROPERTY            421
# C11           M/V ACCIDENT INVOLVING PEDESTRIAN - INJURY            398
# B2                                            AUTO THEFT            330
# B2                                        VERBAL DISPUTE            584
# C6                                      ROBBERY - STREET            177
# C11                                       VERBAL DISPUTE            364
# C6                                        VERBAL DISPUTE            913
# C6                                  INVESTIGATE PROPERTY            936
# D4                   FIRE REPORT - HOUSE, BUILDING, ETC.            139
# B3                             THREATS TO DO BODILY HARM            429
# B3                                       PROPERTY - LOST            469
# NaN                        SICK/INJURED/MEDICAL - PERSON
# C11                                       VERBAL DISPUTE            341
# D4                                   DEMONSTRATIONS/RIOT            130
# B2                             THREATS TO DO BODILY HARM            901
# B2                 LARCENY THEFT FROM MV - NON-ACCESSORY            181
# NaN                        SICK/INJURED/MEDICAL - PERSON
# A1                                  M/V ACCIDENT - OTHER             69
# B3                         SICK/INJURED/MEDICAL - PERSON            434
# E5                        M/V ACCIDENT - PERSONAL INJURY            550
# B2                     BURGLARY - RESIDENTIAL - NO FORCE            911
# NaN                M/V - LEAVING SCENE - PROPERTY DAMAGE
# D4                         SICK/INJURED/MEDICAL - PERSON            172
# C11                             ASSAULT SIMPLE - BATTERY            242
# C11               VIOL. OF RESTRAINING ORDER W NO ARREST            242
# B3                   VAL - VIOLATION OF AUTO LAW - OTHER            463
# ...                                                  ...            ...
# D4                                        WARRANT ARREST            171
# D4                       LARCENY SHOPLIFTING $50 TO $199            171
# A1                         ASSAULT & BATTERY D/W - OTHER             97
# A1                                        WARRANT ARREST             97
# B2                                        WARRANT ARREST            324
# B2                             LARCENY OTHER $200 & OVER            324
# B2                                        WARRANT ARREST            318
# B2                                     ASSAULT & BATTERY            318
# B2                                        WARRANT ARREST            318
# D4                             LARCENY OTHER $50 TO $199            285
# D4                                        WARRANT ARREST            285
# A1                                        WARRANT ARREST             77
# A1                            ROBBERY - UNARMED - STREET             77
# E13                                       WARRANT ARREST            572
# B2                       VAL - OPERATING AFTER REV/SUSP.            304
# B2                       VAL - OPERATING AFTER REV/SUSP.            304
# C11                                       WARRANT ARREST            355
# C11                                       WARRANT ARREST            355
# B3                         ASSAULT & BATTERY D/W - OTHER            458
# B3                                        WARRANT ARREST            458
# A1                                        WARRANT ARREST            111
# A1        DRUGS - POSS CLASS B - INTENT TO MFR DIST DISP            111
# A1                  DRUGS - POSS CLASS B - COCAINE, ETC.            111
# E13          DRUGS - POSS CLASS D - INTENT MFR DIST DISP            912
# E13                                       WARRANT ARREST            912
# D4                                        WARRANT ARREST            285
# E18                  MURDER, NON-NEGLIGIENT MANSLAUGHTER            520
# E18                                       WARRANT ARREST            520
# E13                                       WARRANT ARREST            569
# D4                                        WARRANT ARREST            903
#
#          SHOOTING  OCCURRED_ON_DATE
# DISTRICT
# D14           NaN    9/2/2018 13:00
# C11           NaN    8/21/2018 0:00
# D4            NaN    9/3/2018 19:27
# D4            NaN    9/3/2018 21:16
# B3            NaN    9/3/2018 21:05
# C11           NaN    9/3/2018 21:09
# B2            NaN    9/3/2018 21:25
# B2            NaN    9/3/2018 20:39
# C6            NaN    9/3/2018 20:48
# C11           NaN    9/3/2018 20:38
# C6            NaN    9/3/2018 19:55
# C6            NaN    9/3/2018 20:19
# D4            NaN    9/3/2018 19:58
# B3            NaN    9/3/2018 20:39
# B3            NaN    9/2/2018 14:00
# NaN           NaN    9/3/2018 19:43
# C11           NaN    9/3/2018 18:52
# D4            NaN    9/3/2018 17:00
# B2            NaN    9/3/2018 19:52
# B2            NaN    9/2/2018 18:00
# NaN           NaN    9/3/2018 18:46
# A1            NaN    9/3/2018 18:30
# B3            NaN    9/3/2018 18:42
# E5            NaN    9/3/2018 18:33
# B2            NaN    9/3/2018 18:38
# NaN           NaN    9/3/2018 18:20
# D4            NaN    9/3/2018 18:50
# C11           NaN    9/3/2018 18:34
# C11           NaN    9/3/2018 18:34
# B3            NaN    9/3/2018 18:55
# ...           ...               ...
# D4            NaN   7/22/2015 22:00
# D4            NaN   7/22/2015 22:00
# A1            NaN    6/14/2016 9:40
# A1            NaN    6/14/2016 9:40
# B2            NaN    7/29/2016 0:00
# B2            NaN    7/29/2016 0:00
# B2            NaN   10/2/2015 21:00
# B2            NaN   10/2/2015 21:00
# B2            NaN   10/2/2015 21:00
# D4            NaN    6/5/2016 17:23
# D4            NaN    6/5/2016 17:23
# A1            NaN   7/27/2015 10:47
# A1            NaN   7/27/2015 10:47
# E13           NaN    8/3/2015 16:22
# B2            NaN   7/29/2016 18:20
# B2            NaN   7/29/2016 18:20
# C11           NaN     2/1/2016 1:43
# C11           NaN     2/1/2016 1:43
# B3            NaN  11/20/2015 11:15
# B3            NaN  11/20/2015 11:15
# A1            NaN   8/12/2015 12:00
# A1            NaN   8/12/2015 12:00
# A1            NaN   8/12/2015 12:00
# E13           NaN   1/27/2018 14:01
# E13           NaN   1/27/2018 14:01
# D4            NaN    6/5/2016 17:25
# E18           NaN    7/9/2015 13:38
# E18           NaN    7/9/2015 13:38
# E13           NaN   5/31/2016 19:35
# D4            NaN    6/22/2015 0:12
#
# [319073 rows x 6 columns]

# %%
# data_combine = pd.merge(Crime_data_trunc,clinical_data, how='left', on=["District", "District"])

# %% [markdown]
# #                               Transformation - District

# %%
dist_data_clean[District_Address] =(dist_data_clean['District Names'].str.split(',').str[0]
# Out:
#     Unnamed: 0  District Codes  \
# 0            0    District A-7
# 1            1    District B-2
# 2            2    District B-3
# 3            3    District C-6
# 4            4   District C-11
# 5            5    District D-4
# 6            6   District D-14
# 7            7    District E-5
# 8            8   District E-13
# 9            9   District E-18
# 10          10   District A-1
# 11          11  District  A-15
#
#                                      District Names
# 0            69 Paris Street, East Boston, MA 02128
# 1         2400 Washington Street, Roxbury, MA 02119
# 2         1165 Blue Hill Avenue, Mattapan, MA 02124
# 3         101 West Broadway, South Boston, MA 02127
# 4            40 Gibson Street, Dorchester, MA 02122
# 5             650 Harrison Avenue, Boston, MA 02116
# 6         301 Washington Street, Brighton, MA 02135
# 7        1708 Centre Street, West Roxbury, MA 02132
# 8   3347 Washington Street, Jamaica Plain, MA 02130
# 9        1249 Hyde Park Avenue, Hyde Park, MA 02136
# 10           40 New Sudbury Street Boston, MA 02114
# 11           40 New Sudbury Street Boston, MA 02114

# %%
dist_data_clean = pd.DataFrame()
dist_data_clean['District_Address'] =(dist_data['District Names'].str.split(',').str[0])
dist_data_clean['District'] =(dist_data['District Names'].str.split(',').str[1])   
dist_data_clean
# Out:
#                 District_Address        District
# 0                69 Paris Street     East Boston
# 1         2400 Washington Street         Roxbury
# 2          1165 Blue Hill Avenue        Mattapan
# 3              101 West Broadway    South Boston
# 4               40 Gibson Street      Dorchester
# 5            650 Harrison Avenue          Boston
# 6          301 Washington Street        Brighton
# 7             1708 Centre Street    West Roxbury
# 8         3347 Washington Street   Jamaica Plain
# 9          1249 Hyde Park Avenue       Hyde Park
# 10  40 New Sudbury Street Boston        MA 02114
# 11  40 New Sudbury Street Boston        MA 02114

# %%
# Out:
#   File "<ipython-input-49-491e38b31a05>", line 3
#     d1=dist_data_clean[dist_data_clean['District_Address']=('40 New Sudbury Street Boston') ]
#                                                           ^
# SyntaxError: invalid syntax

# %%
dist_data_clean.loc[dist_data_clean['District_Address'].isin(['40 New Sudbury Street Boston'])]='40 New Sudbury Street'

# %%
dist_data_clean.replace('40 New Sudbury Street Boston', '40 New Sudbury Street')
# Out:
#           District_Address        District
# 0          69 Paris Street     East Boston
# 1   2400 Washington Street         Roxbury
# 2    1165 Blue Hill Avenue        Mattapan
# 3        101 West Broadway    South Boston
# 4         40 Gibson Street      Dorchester
# 5      650 Harrison Avenue          Boston
# 6    301 Washington Street        Brighton
# 7       1708 Centre Street    West Roxbury
# 8   3347 Washington Street   Jamaica Plain
# 9    1249 Hyde Park Avenue       Hyde Park
# 10   40 New Sudbury Street        MA 02114
# 11   40 New Sudbury Street        MA 02114

# %%
# Out:
#                 District_Address        District
# 0                69 Paris Street     East Boston
# 1         2400 Washington Street         Roxbury
# 2          1165 Blue Hill Avenue        Mattapan
# 3              101 West Broadway    South Boston
# 4               40 Gibson Street      Dorchester
# 5            650 Harrison Avenue          Boston
# 6          301 Washington Street        Brighton
# 7             1708 Centre Street    West Roxbury
# 8         3347 Washington Street   Jamaica Plain
# 9          1249 Hyde Park Avenue       Hyde Park
# 10  40 New Sudbury Street Boston        MA 02114
# 11  40 New Sudbury Street Boston        MA 02114

# %%
dist_data_clean['District']
# Out:
# 0        East Boston
# 1            Roxbury
# 2           Mattapan
# 3       South Boston
# 4         Dorchester
# 5             Boston
# 6           Brighton
# 7       West Roxbury
# 8      Jamaica Plain
# 9          Hyde Park
# 10          MA 02114
# 11          MA 02114
# Name: District, dtype: object
